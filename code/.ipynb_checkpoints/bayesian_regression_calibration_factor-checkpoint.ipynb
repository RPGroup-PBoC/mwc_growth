# %% [markdown]
# # Bayesian Parameter Estimation for α

# %%
import numpy as np
import pandas as pd
import scipy.special
import emcee

import bokeh.io
import bokeh.plotting
import bokeh.themes
import bokeh.document

import pickle
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b0d0d077-ceeb-4d57-859d-718c63bece21">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
#  In this notebook, I will write a Bayesian model for determination of the calibration factor $\alpha$, will test it out on some simulated data, and will then test it on some real data from Brewster et al. 2014.

# %% [markdown]
# ## The Model

# %% [markdown]
# Rather than binning the data t compute the calibration factor, I can perform a complete Bayesian regression for the parameter knowing my assumptions about the distribution of protein molecules. The crux of the model is that the intensity of one cell $I_1$ is related to the number of fluorescent protein molecules $N_1$ by a calibration $\alpha$ such that
#
# $$
# I_1 = \alpha N_1.
# $$
#
# It's important to note that the number of pretin molecules across a pair of daughter cells is conserved,
#
# $$
# N_{tot} = N_1 + N2 \Rightarrow N2 = N_{tot} - N_1.
# $$
#
# Therefore, the intensity is also conserved,
#
# $$
# I_{tot} = I_1 + I_2.
# $$
#
# Of course, there is lots of measurement error in the measurement of intensity. Using Bayes's rule, I can write down the posterior distribution I want to calculate as
#
# $$
# P(\alpha, \sigma, N_1, N_{tot}\, \vert \, I_1, I_2) \propto P(I_1, I_2 \, \vert \, \alpha, N_1, N_{tot})P(\alpha, \sigma, N_1, N_{tot}).
# $$
#
# Let's treat the likelihoods and priors with a little more rigor.
#
# <br />
# ### Likelihoods
# There are really three likelihoods -- one for $I_1$, one for $I_2$, and one for $N_1$. We can make the assumption that the actual intensity measurements are gaussian distributed for each cell since there are a lot of processes that contribute to the the fluoresence of a single molecule. We can write the likelihoods for the two intensities $I_1$ and $I_2$ as
#
# $$
# P(I_1 \, \vert \, \alpha, \sigma, N_1, N_{tot}) = {1 \over \sqrt{2 \pi \sigma^2}}\exp\left[{-(I_1 - \alpha N_1)^2 \over 2 \sigma^2}\right]
# $$
#
# and
#
# $$
# P(I_2 \, \vert \, \alpha, \sigma, N_1, N_{tot}) = {1 \over \sqrt{2 \pi \sigma^2}}\exp\left[{-(I_2 - \alpha(N_{tot} - N_1))^2 \over 2\sigma^2}\right].
# $$
#
# We know that the actual protein partitioning across the two daughter cells should be Binomially distributed, allowing us to write the likelihood for $N_1$ as
#
# $$
# P(N_1\, \vert N_{tot}, p) = {N_{tot}! \over N_1!(N_{tot} - N_1)!}p^{N_1}(1-p)^{N_{tot} - N_1}.
# $$
#
# If we make the assumption that partitioning between the two daughter cells is equal such that $p = 1/2$, the likelihood simplifies to
#
# $$
# P(N_1\, \vert N_{tot}) = {N_{tot}! \over N_1!(N_{tot} - N_1)!}\left({1 \over 2}\right)^{N_{tot}}.
# $$
#
# <br/>
# ### Priors
#
# The priors are relatively simple for this case. We have separate priors for the calibration factor $\alpha$, $N_1$, and our uncertainty $\sigma$. It's fair to say that the priors for $\alpha$ and $N_1$ should be uniform, however the latter should be discrete uniform,
#
# $$
# P(\alpha) = \begin{cases}
# {1 \over {\alpha_{max} - \alpha_{min}}},& \alpha_{min} \leq \alpha \leq \alpha_{max}\\
# 0 & \text{otherwise}
# \end{cases}
# $$
#
# and
#
# $$
# P(N_1) = \begin{cases}
# {1 \over {N_{max} - N_{min}}}, & N_{min} \leq N_1 \leq N_{max}\\
# 0 &\text{otherwise}
# \end{cases}.
# $$
#
# As $\sigma$ is a scale parameter, we can just simply use a Jeffrey's prior,
#
# $$
# P(\sigma) = {1 \over \sigma}.
# $$
#
# <br/>
# ### Full Posterior
# Everything written so far is true for a *singele* cell division event. However, we will be looking over *many* cell division events to determine $\alpha$. We therefore need to adapt the likelihoods and priors written here to account for a the posterior for a full data set. We can just multiply the probailiteies together as they are simply independent,
#
# $$
# P(\alpha, \sigma, {N_{1,i}, N_{tot,i}}\,\vert\, I_1, I_2) =\\ {1 \over \sigma}\prod\limits_{i}^n{N_{tot,i}\choose{N_{1,i}}}\left({1 \over \sqrt{2\pi\sigma^2}}\right)^n\exp\left[\left(-{1 \over 2\sigma^2}\right)^n\sum\limits_{i}^n \left((I_{1,i} + \alpha N_{1,i})^2 + (I_{2,i} - \alpha (N_{tot,i} - N_{1,i}))^2\right)\right].
# $$
#
# While complete, it's pretty gross. Rather than analytically marginalize over $\sigma$, I can simply turn to the beauty of MCMC to just sample the distribution. I can then just ignore the sampler flatchains for $\sigma$ and look at the parameter probability distribution for $\alpha$ directly.

# %% [markdown]
# ## Implementation  with MCMC

# %% [markdown]
# To test whether this approach is giving me the correct parameter values, I would like to try it on a sample data set where I **know** the value of $\alpha$. Back in June, I performed a realistic simulation of the dilution experiment where I introduced measurement noise into the value of $\alpha$. For that set I chose $\alpha = 150$ with a standard deviation of $10$ counts per molecule. Let's take a look at the squared intensity difference vs the sum.

# %%
# Load the data. 
sim_data = pd.read_csv('../../data/other/simulated_dilution.csv')
sim_data['summed_int'] = sim_data['I_1'] + sim_data['I_2']
sim_data['squared_diff'] = (sim_data['I_1'] - sim_data['I_2'])**2

# Sample a small section of the data for computational simplicity. 
sim_data = sim_data.sample(500)
         
# Compute the theory line. 
I_tot = np.logspace(2, 7, 200)
alpha = sim_data['seeded_alpha'].unique()
theory = alpha * I_tot
    
# Set up the figure canvas
p = bokeh.plotting.figure(height=400, x_axis_label='summed intensity', 
                          y_axis_label='squared difference', 
                          x_axis_type='log', y_axis_type='log')

# Plot the points and theory.
p.scatter(x='summed_int', y='squared_diff', source=sim_data, color='slategrey', 
          alpha=0.4)
p.line(I_tot, theory, color='tomato', line_width=2,
       legend='α = {0} a.u. per molecule'.format(alpha[0]))
p.legend.location = 'top_left'
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3cd2cd22-5243-4afb-be25-cf1a4421a63c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3cd2cd22-5243-4afb-be25-cf1a4421a63c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3cd2cd22-5243-4afb-be25-cf1a4421a63c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3cd2cd22-5243-4afb-be25-cf1a4421a63c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"75af624a-3dd4-4477-8b04-f2dd8513a332":{"roots":{"references":[{"attributes":{"label":{"value":"\u03b1 = 150.0 a.u. per molecule"},"renderers":[{"id":"19171add-e841-4c21-a0a0-b2f8e2bf0511","type":"GlyphRenderer"}]},"id":"b7207ffa-0c14-4f88-8e69-3cc73935b380","type":"LegendItem"},{"attributes":{"ticker":null},"id":"fd232387-a2b8-4042-8cbc-74f1648c3890","type":"LogTickFormatter"},{"attributes":{"plot":null,"text":""},"id":"f3380369-5430-4637-a9fd-92c2f9fe0a0f","type":"Title"},{"attributes":{"items":[{"id":"b7207ffa-0c14-4f88-8e69-3cc73935b380","type":"LegendItem"}],"location":"top_left","plot":{"id":"34182082-f44d-4828-babc-b2c6917b3d70","subtype":"Figure","type":"Plot"}},"id":"7936bdd2-1082-4a35-924e-9dc0a9a0a7db","type":"Legend"},{"attributes":{"ticker":null},"id":"dbf96e34-c044-41d7-8d4a-abc6d642cfed","type":"LogTickFormatter"},{"attributes":{"data_source":{"id":"d2fc854e-cf7e-40e1-b9ec-8741acbf2df1","type":"ColumnDataSource"},"glyph":{"id":"fadde1d0-6566-49c1-9d34-9c4a38d00c62","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"c918635c-3012-4a04-85bf-a9d5c107e3c6","type":"Circle"},"selection_glyph":null},"id":"5a0973f8-c5a0-4eda-a6c3-0cac1cfb3c13","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"4bc1bd20-51c7-418e-9eda-c412ef496fdb","type":"BoxAnnotation"},"plot":{"id":"34182082-f44d-4828-babc-b2c6917b3d70","subtype":"Figure","type":"Plot"}},"id":"5297139c-5ca5-4a57-b8a0-c7762ac1b804","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"0d9c0907-1e03-42bb-813f-9dc1a313d58c","type":"ColumnDataSource"},"glyph":{"id":"cd7525ce-c96a-44c0-b92c-18cfc1dd2edb","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"50f80a32-ac53-4bd9-b1c5-2d1ba676612a","type":"Line"},"selection_glyph":null},"id":"19171add-e841-4c21-a0a0-b2f8e2bf0511","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"34182082-f44d-4828-babc-b2c6917b3d70","subtype":"Figure","type":"Plot"}},"id":"2f79efe6-a134-4d1d-8e9d-ab71c3bbff5c","type":"SaveTool"},{"attributes":{"plot":{"id":"34182082-f44d-4828-babc-b2c6917b3d70","subtype":"Figure","type":"Plot"}},"id":"7340f599-e079-4e91-9051-abd5157bc383","type":"HelpTool"},{"attributes":{"callback":null},"id":"e82cc289-e0fc-497f-9c4e-9cd385455640","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"50f80a32-ac53-4bd9-b1c5-2d1ba676612a","type":"Line"},{"attributes":{},"id":"f0ad3bde-5840-48b4-9148-e3475b3a683d","type":"ToolEvents"},{"attributes":{"callback":null},"id":"dd5497d8-00e8-43ed-bd8a-235f084590cf","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"03b53ab4-cb55-41aa-9616-1f031c99fd8a","type":"PanTool"},{"id":"0178e3f5-cb4c-45bf-b805-ab24051ec5cf","type":"WheelZoomTool"},{"id":"5297139c-5ca5-4a57-b8a0-c7762ac1b804","type":"BoxZoomTool"},{"id":"2f79efe6-a134-4d1d-8e9d-ab71c3bbff5c","type":"SaveTool"},{"id":"83dec6d3-cce4-48af-aea6-e1a8adc04735","type":"ResetTool"},{"id":"7340f599-e079-4e91-9051-abd5157bc383","type":"HelpTool"}]},"id":"4f0274cf-e2d5-47e1-be53-5f55ac6c498b","type":"Toolbar"},{"attributes":{"line_color":{"value":"tomato"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd7525ce-c96a-44c0-b92c-18cfc1dd2edb","type":"Line"},{"attributes":{"below":[{"id":"71ae59f1-e174-46f0-9e9b-0d5db061efc0","type":"LogAxis"}],"left":[{"id":"6eced0ba-db5b-4bf3-a6e1-a1969272365b","type":"LogAxis"}],"plot_height":400,"renderers":[{"id":"71ae59f1-e174-46f0-9e9b-0d5db061efc0","type":"LogAxis"},{"id":"2b6e27ef-f553-4fd0-a29a-f619f4219092","type":"Grid"},{"id":"6eced0ba-db5b-4bf3-a6e1-a1969272365b","type":"LogAxis"},{"id":"3ca0058a-ec9a-4c08-a93e-c4a110c59de3","type":"Grid"},{"id":"4bc1bd20-51c7-418e-9eda-c412ef496fdb","type":"BoxAnnotation"},{"id":"5a0973f8-c5a0-4eda-a6c3-0cac1cfb3c13","type":"GlyphRenderer"},{"id ...

# %% [markdown]
# To perform the MCMC, we need to have a function to compute the log posterior. For clarity, I'll break this into three functions $-$ `log_prior` for the priors, `log_like` for the likelihood, and `log_post` which calls both.
#
# I need to impose actual values for the priors. As I showed up above, I'm assuming a uniform prior on both $\alpha$ and the protein copy number, meaning I have to settle on $max$ and $min$ values for each.
#
# For the bounds on $\alpha$, I can use some of my knowledge of the experiment. I know that I will be using a camera to make these measurements. I also know that I'll be careful not to overexpose my images. Therefore, I know that the calibration factor has to be in the range dictated by the bit depth of the camera. Assuming I use a fancy 16-bit EMCCD camera,
#
# $$
# P(\alpha) = {1 \over \alpha_{max} - \alpha_{min}} = {1 \over (2^{16} - 1) - 0} = 65.535\times 10^{-3}.
# $$
#
#
# The protein copy number is a little bit more tricky as I have to figure out what the absolute maximum copy number could be for a cell. I know that the typical size of a protein is about $1\, \text{nm}^3 \approx 10^{-9}\, \text{fL}$. Approximating a standard *E. coli* cell as 1 fL bag of water, I could at absolute most fit $10^9$ proteins per cell, ignoring the fact that there are other things taking up the volume of the cell. Nevertheless, this seems like OK bound to use. My prior on $N$ is therefore,
#
# $$
# P(N_1) = {1 \over N_{max} - N_{min}} = {1 \over 10^9 - 0} = 10^{-9}.
# $$
#
# While I don't need any hard numbers to deal with for the Jeffrey's prior on $\sigma$, I have to make sure that my walkers don't use 0. Therefore I'll return the prior as
#
# $$
# P(\sigma) = \begin{cases}
#         \sigma^{-1} & 10^{-9} \leq \sigma \leq \infty\\
#         -\infty & \text{otherwise}
#         \end{cases}
# $$
#
# I've hard-coded these values into the `log_prior` function below.

# %%
def log_prior(p, n):
    """Priors for alpha, sigma, and protein copy numbers."""
    alpha, sigma = p[0], p[1]
    
    # Extract the protein copy numbers and convert to integer. 
    n1 = p[2:n+2].astype(int)
    ntot = p[n+2:]
    
    # Apply the priors. 
    if p.any() < 0:
        return -np.inf
    if (n1 > n_tot).any():
        return -np.inf
    
    # Apply the hard-coded bounds.
    if (alpha > (2**16 -1)):
        return -np.inf
    if (n1 > 1E9) | (ntot > 1E9):
        return -np.inf
    if sigma < 1E-9:
        return -np.inf
    
    # Compute the actual priors and return. 
    return  -np.log(sigma)

def log_like(p, I_1, I_2):
    """Computes the log likelihood."""
    
    # Unpack the parameters.
    alpha, sigma = p[0], p[1]
    n1 = p[2:n+2].astype(int)
    ntot = p[n+2:].astype(int)
    
    # Compute the log likelihood in sections so it's easier to return.   
    log_binom = (scipy.special.gammaln(ntot + 1) -\
                 scipy.special.gammaln(n1 + 1) -\
                 scipy.special.gammaln(ntot - n1 + 1)).sum()      
    log_sigma = -np.log(sigma) - (len(I_1) / 2) * np.log(2 * np.pi * sigma**2)
    log_norms = (-2 * sigma**2)**(-len(I_1)) * (-(I_1 - alpha * n1)**2 -\
                (I_2 - alpha * (ntot - n1)**2)).sum()
    return log_binom + log_sigma + log_norms

def log_post(p, I_1, I_2):
    """Combine the prior and likelihood for clarity"""
    lnp = log_prior(p, len(I_1))
    if lnp == -np.inf:
        return -np.inf
    return lnp + log_like(p, I_1, I_2)

# %% [markdown]
# Now I can set up the parameters for the MCMC.

# %%
# Define the various parameters of the MCMC.
num_div = len(sim_data)
n_burn = 500 # Number of burn-in steps. 
n_steps = 1000 # Number of steps for each walker. 
n_dim = 2 * num_div + 2
n_walkers = 3 * n_dim

# Set the initial guesses and populate the starting positions. 
n_1 = sim_data['N_1']
n_tot = sim_data['N_1'] + sim_data['N_2']
p0 = np.empty((n_walkers, n_dim))
p0[:,0] = np.random.normal(alpha, scale=10, size=n_walkers)
p0[:,1] = np.random.normal(10, scale=10, size=n_walkers)
p0[:,2:num_div+2] = np.random.uniform(1, 1E9,size=(n_walkers, num_div))
p0[:,num_div+2:] = np.random.uniform(1, 1E9, size=(n_walkers, num_div))

# Set up the sampler using threading. 
sampler = emcee.EnsembleSampler(n_walkers, n_dim, log_post,
                                args=(sim_data['I_1'], sim_data['I_2']), threads=8)

# %%
# Perform the burn-in and then sample. 
print('Beginning the burn-in...')
pos, prob, state = sampler.run_mcmc(p0, n_burn, storechain=False)
print('Finished! Now sampling....')
_ = sampler.run_mcmc(pos, n_steps, thin=100)
print('whew. That was rough. ')
# Out:
# Beginning the burn-in...
# /Users/gchure/anaconda/lib/python3.6/site-packages/emcee/ensemble.py:335: RuntimeWarning: invalid value encountered in subtract
#   lnpdiff = (self.dim - 1.) * np.log(zz) + newlnprob - lnprob0
# /Users/gchure/anaconda/lib/python3.6/site-packages/emcee/ensemble.py:336: RuntimeWarning: invalid value encountered in greater
#   accept = (lnpdiff > np.log(self._random.rand(len(lnpdiff))))
# Finished! Now sampling....
# whew. That was rough.

# %%
# For safety, save the flatchain as a pickle
output = open('../../data/other/dilution_simulation_flatchain.pkl', 'wb')
pickle.dump(sampler.flatchain, output)
pickle.dump(sampler.flatlnprobability, output)
output.close() # close it to make sure it's all been written

# %% [markdown]
# Since I have 502 parameters, I can't show the distribution for everything. However, I can plot the marginalized distribution for the posterior on $\alpha$. Rather than computing the mean and standard deviation, I'll opt to compute the mode and the credible region showing 95% of the sample density.

# %%
# #################
def hpd(trace, mass_frac):
    """
    Returns highest probability density region given by
    a set of samples.
    Parameters
    ----------
    trace : array
        1D array of MCMC samples for a single variable
    mass_frac : float with 0 < mass_frac <= 1
        The fraction of the probability to be included in
        the HPD.  For hreple, `massfrac` = 0.95 gives a
        95% HPD.

    Returns
    -------
    output : array, shape (2,)
        The bounds of the HPD

    Notes
    -----
    We thank Justin Bois (BBE, Caltech) for developing this function.
    http://bebi103.caltech.edu/2015/tutorials/l06_credible_regions.html
    """
    # Get sorted list
    d = np.sort(np.copy(trace))

    # Number of total samples taken
    n = len(trace)

    # Get number of samples that should be included in HPD
    n_samples = np.floor(mass_frac * n).astype(int)

    # Get width (in units of data) of all intervals with n_samples samples
    int_width = d[n_samples:] - d[:n - n_samples]

    # Pick out minimal interval
    min_int = np.argmin(int_width)

    # Return interval
    return np.array([d[min_int], d[min_int + n_samples]])

# %%
# Compute the histogram for the posterior distribution of alpha.
hist, edges = np.histogram(sampler.flatchain[:,0], bins=75)

# Compute the mode and HPD from the flatlnprob. 
ind = np.argmax(sampler.flatlnprobability)
mode = sampler.flatchain[ind,0]
# # Set up the figure
p = bokeh.plotting.figure(height=400)
p.line(sampler.flatchain[:,0], sampler.flatlnprobability)
# p.quad(top=hist, bottom=0, left=edges[1:], right=edges[:-1], line_color='black')
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="217eb144-3e9a-4724-8119-c0523b0d3984"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("217eb144-3e9a-4724-8119-c0523b0d3984");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("217eb144-3e9a-4724-8119-c0523b0d3984");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '217eb144-3e9a-4724-8119-c0523b0d3984' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cc8c5210-deb5-4013-bcdc-15996ea0cd5b":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"33373c7f-a86a-4b2c-97d5-00c34b9d783f","type":"Title"},{"attributes":{"formatter":{"id":"ed7dead9-e041-460a-a228-7ea58849f902","type":"BasicTickFormatter"},"plot":{"id":"bb5c5712-3c90-44c9-9c11-9ac8ae77aa87","subtype":"Figure","type":"Plot"},"ticker":{"id":"82219f60-3926-440b-bf8b-b4c432c0c4d1","type":"BasicTicker"}},"id":"58f361d3-bbec-4bd6-9199-1cb6b606ebd8","type":"LinearAxis"},{"attributes":{"below":[{"id":"fc23f966-fb7f-424f-bbe7-d70200ac7b5d","type":"LinearAxis"}],"left":[{"id":"58f361d3-bbec-4bd6-9199-1cb6b606ebd8","type":"LinearAxis"}],"plot_height":400,"renderers":[{"id":"fc23f966-fb7f-424f-bbe7-d70200ac7b5d","type":"LinearAxis"},{"id":"ec6a1da6-4994-4f75-9b73-47b1e013b3b0","type":"Grid"},{"id":"58f361d3-bbec-4bd6-9199-1cb6b606ebd8","type":"LinearAxis"},{"id":"5999106e-7c7e-479b-968b-4f6d415a829c","type":"Grid"},{"id":"f5a92892-550c-4fe6-9cd4-d3625e95bf22","type":"BoxAnnotation"},{"id":"3c81da42-b151-4408-bc72-11908101b844","type":"GlyphRenderer"}],"title":{"id":"33373c7f-a86a-4b2c-97d5-00c34b9d783f","type":"Title"},"tool_events":{"id":"2564e8d9-66f5-4ec0-b3d6-5394ee421caa","type":"ToolEvents"},"toolbar":{"id":"811cfbee-35bc-4250-87af-51b674bdafb8","type":"Toolbar"},"x_range":{"id":"561ecbba-2a49-42d9-a416-64f90d9f24d0","type":"DataRange1d"},"x_scale":{"id":"ceffdeb2-0d47-4a14-abec-f3b3194fd555","type":"LinearScale"},"y_range":{"id":"94fded03-e7ce-4c2c-b93b-b5331ad708a2","type":"DataRange1d"},"y_scale":{"id":"e4280191-d271-4aa2-9ad8-7efba68a2a96","type":"LinearScale"}},"id":"bb5c5712-3c90-44c9-9c11-9ac8ae77aa87","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"82219f60-3926-440b-bf8b-b4c432c0c4d1","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"bb5c5712-3c90-44c9-9c11-9ac8ae77aa87","subtype":"Figure","type":"Plot"},"ticker":{"id":"82219f60-3926-440b-bf8b-b4c432c0c4d1","type":"BasicTicker"}},"id":"5999106e-7c7e-479b-968b-4f6d415a829c","type":"Grid"},{"attributes":{"data_source":{"id":"8adaff77-959e-496e-8b1d-3f46f98f18f2","type":"ColumnDataSource"},"glyph":{"id":"1d01a3be-a1ab-4455-a6d5-26f6a4b99613","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"18af46bd-df0c-41c0-a7c0-740ca399a738","type":"Line"},"selection_glyph":null},"id":"3c81da42-b151-4408-bc72-11908101b844","type":"GlyphRenderer"},{"attributes":{},"id":"e4280191-d271-4aa2-9ad8-7efba68a2a96","type":"LinearScale"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"18af46bd-df0c-41c0-a7c0-740ca399a738","type":"Line"},{"attributes":{},"id":"ed7dead9-e041-460a-a228-7ea58849f902","type":"BasicTickFormatter"},{"attributes":{},"id":"6dc7862a-eab7-4322-96fa-541b344d0373","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f5a92892-550c-4fe6-9cd4-d3625e95bf22","type":"BoxAnnotation"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d01a3be-a1ab-4455-a6d5-26f6a4b99613","type":"Line"},{"attributes":{"plot":{"id":"bb5c5712-3c90-44c9-9c11-9ac8ae77aa87","subtype":"Figure","type":"Plot"}},"id":"b8e444d6-621d-48ba-b880-2cb94e546f44","type":"PanTool"},{"attributes":{},"id":"8ade96a5-baa4-4188-8575-776da68345c1","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"561ecbba-2a49-42d9-a416-64f90d9f24d0","type":"DataRange1d"},{"attributes":{"plot":{"id":"bb5c5712-3c90-44c9-9c11-9ac8ae77aa87","subtype":"Figure","type":"Plot"}},"id":"6a482cc8-84f5-487b-a399-7786f82df145","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"f5a92892-550c-4fe6-9cd4-d3625e95bf22","type":"BoxAnnotatio ...

# %%
sampler.flatchain[ind,0]
# Out:
# 146.59716975780518

# %%
np.mean(sampler.flatchain[:,0])
# Out:
# 150.16985913225912

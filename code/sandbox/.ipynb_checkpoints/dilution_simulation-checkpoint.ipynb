# %% [markdown]
# #  Simulating the dilution experiment.

# %%
import numpy as np
import pandas as pd
import bokeh.charts
import bokeh.charts.utils
import bokeh.io
import bokeh.models
import bokeh.palettes
import bokeh.plotting

# Display graphics in this notebook
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8da2ba15-c8c9-4c49-9b22-1468948c9d99">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Setting up the problem.

# %% [markdown]
# ## Generating a data set

# %%
# Define some parameters. 
alpha = 150 # in arbitrary units
int_range = np.logspace(0, 4, 100)  # I_tot range for the calculation.
max_divisions = 50 # number of division events recorded for each intensity. 
partition_prob = 0.5 # 

# Set up a vector to store the squared differences. 
square_dif = np.zeros((num_divisions, len(int_range)))
df = pd.DataFrame(columns=['square_diff', 'I_tot'])
# Loop through each intensity value. 
for i, I_tot in enumerate(int_range):
    # Loop through each division event. 
    random_div_num = np.random.choice(np.arange(0, num_divisions,1))
    for div in range(random_div_num):
        # Set the noise in the alpha value. 
        alpha_noise = np.random.normal(alpha, 10)  # Add some gaussian norm. 
        
        # Apply noise to the intensity.
        I_tot = np.random.normal(I_tot, 0.1 * I_tot)
        # Compute the number that are partitioned. 
        N_tot = int(I_tot / alpha_noise)
        N_1 = np.sum(np.random.rand(N_tot) < partition_prob)
        square_diff = (alpha_noise * (N_1 - N_tot + N_1))**2
        df = df.append({'square_diff' : square_diff, 'I_tot' : I_tot},
                      ignore_index=True)

# %%
p = bokeh.charts.Scatter(df, x='I_tot', y='square_diff', height=500,
                         width=600, color='dodgerblue')
bokeh.io.show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="db5236fb-8680-42d9-b56f-ef4844b4452a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("db5236fb-8680-42d9-b56f-ef4844b4452a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db5236fb-8680-42d9-b56f-ef4844b4452a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db5236fb-8680-42d9-b56f-ef4844b4452a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6db2f71a-f79a-4a2b-8e61-04cc05f6dd7f":{"roots":{"references":[{"attributes":{"below":[{"id":"1e84622a-50be-42f9-b4f7-dd5fd89b1982","type":"LinearAxis"}],"css_classes":null,"height":500,"left":[{"id":"61396bd8-364a-4c58-a31b-92f4807973fc","type":"LinearAxis"}],"renderers":[{"id":"07924ae8-7f97-4fc7-8b32-06242cb123bd","type":"BoxAnnotation"},{"id":"d696c20b-6d68-452d-82c8-da30c3aa2356","type":"GlyphRenderer"},{"id":"f91fa3a9-7561-4901-9865-f9b2fe319969","type":"Legend"},{"id":"1e84622a-50be-42f9-b4f7-dd5fd89b1982","type":"LinearAxis"},{"id":"61396bd8-364a-4c58-a31b-92f4807973fc","type":"LinearAxis"},{"id":"bbc473ca-2bc4-4eeb-8009-947174a5a24b","type":"Grid"},{"id":"f97bdd52-81b9-47f7-85f7-9db13e4c98d4","type":"Grid"}],"title":{"id":"15da242c-09d4-4370-abc3-477ce8aeb05c","type":"Title"},"tool_events":{"id":"42d7473e-d6c5-4059-ad08-69bf486fba15","type":"ToolEvents"},"toolbar":{"id":"8acaa4df-9035-4dba-bc92-09bae8c690b8","type":"Toolbar"},"width":600,"x_mapper_type":"auto","x_range":{"id":"405887a8-c803-4272-968c-2dcb3327a1e2","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"3c482705-2133-412d-b31f-246c31c8af21","type":"Range1d"}},"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"07924ae8-7f97-4fc7-8b32-06242cb123bd","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"},"ticker":{"id":"e5eaf353-dd87-4f13-b538-895b839b6798","type":"BasicTicker"}},"id":"bbc473ca-2bc4-4eeb-8009-947174a5a24b","type":"Grid"},{"attributes":{"overlay":{"id":"07924ae8-7f97-4fc7-8b32-06242cb123bd","type":"BoxAnnotation"},"plot":{"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"}},"id":"f82af872-ae17-48ef-adc6-92b6df647d64","type":"BoxZoomTool"},{"attributes":{"location":"top_left","plot":{"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"}},"id":"f91fa3a9-7561-4901-9865-f9b2fe319969","type":"Legend"},{"attributes":{},"id":"f4721914-12bb-479c-9d56-db43c6f99115","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"}},"id":"006c8f24-81b7-49ed-b5ab-6da609f1ec59","type":"SaveTool"},{"attributes":{"callback":null,"end":14796.51936645745,"start":-1344.7216134372488},"id":"405887a8-c803-4272-968c-2dcb3327a1e2","type":"Range1d"},{"attributes":{"plot":null,"text":null},"id":"15da242c-09d4-4370-abc3-477ce8aeb05c","type":"Title"},{"attributes":{},"id":"42d7473e-d6c5-4059-ad08-69bf486fba15","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"},"ticker":{"id":"ab0ead8d-ad59-41b7-9373-e43351c48c6c","type":"BasicTicker"}},"id":"f97bdd52-81b9-47f7-85f7-9db13e4c98d4","type":"Grid"},{"attributes":{"plot":{"id":"89f1c4c4-b42d-4bd1-b8d9-946c82e33336","subtype":"Chart","type":"Plot"}},"id":"1ff0997e-a7ca-4c0a-b562-0c8d2f978fca","type":"ResetTool"},{"attributes":{},"id":"e5eaf353-dd87-4f13-b538-895b839b6798","type":"BasicTicker"},{"attributes":{"callback":null,"end":8224765.445734277,"start":-747705.9496122071},"id":"3c482705-2133-412d-b31f-246c31c8af21","type":"Range1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a486b0c5-ae7c-4b95-8a72-d0b08682597e","type":"PanTool"},{"id":"b0b82dd2-bee3-496b-8458-b381392a24ec","type":"WheelZoomTool"},{"id":"f82af872-ae17-48ef-adc6-92b6df647d64","type":"BoxZoomTool"},{"id":"006c8f24-81b7-49ed-b5ab-6da609f1ec59","type":"SaveTool"},{"id":"1ff0997e-a7ca-4c0a-b562-0c8d2f978fca","type":"ResetTool"},{"id":"6c9880f7-fd4b-4bd4-9c49-28eb57dbe102"," ...

# %%
random_div_num
# Out:
# 34
